# %% [markdown]
# # Analysis of Anscombe's Quartet Dataset

# %% [markdown]
# Anscombe's quartet was constructed in 1973 by the English statistician Francis Anscombe.
# ![image.png](attachment:image.png)
#
# It comprises four datasets that have nearly identical simple descriptive statistics, yet appear very different when graphed. Each dataset consists of eleven (x,y) points.
#
# The purpose of the datasset is to demonstrate both the importance of graphing data before analyzing it and the effect of outliers on statistical properties. (https://en.wikipedia.org/wiki/Anscombe's_quartet)
#
# The 4 data sets have the following statistical properties in common: (http://brianmc.dbsdataprojects.com/2016/02/29/analysis-of-anscombes-quartet/)
# - The mean for x is the same for each data set
# - The mean for y is the same for each data set
# - The variance the correlation between x and y is the same for each data set
# - The linear regression for each dataset follows the equation y = 0.5x + 3
#
# However, When the data sets are plotted the common statistical properties are not visually evident and highlight the varience within the datasets.
#
# It is not known how Anscombe created the datasets but the purpose of them is to highlight the importance of data visualisation prior to analysis.

# %%
import numpy as np  # import numnerical python with shorthand  
import matplotlib.pyplot as plt  # shorthand import for matplotlib library
import seaborn as sns # import seaborn for advanced graphics
import pandas as pd # import pandas to take data from table in csv file
sns.set(style="ticks")

# %%
df = pd.read_csv("Anscombes Dataset.csv")

# %%
df
# Out:
#     x1     y1  x2    y2  x3     y3  x4     y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %%
# Display the mean of each column
mean = df.mean()

# %%
mean
# Out:
# x1    9.000000
# y1    7.500909
# x2    9.000000
# y2    7.500909
# x3    9.000000
# y3    7.500000
# x4    9.000000
# y4    7.500909
# dtype: float64

# %%
mean.plot.bar()

# %%
var = df.var()

# %%
var
# Out:
# x1    11.000000
# y1     4.127269
# x2    11.000000
# y2     4.127629
# x3    11.000000
# y3     4.122620
# x4    11.000000
# y4     4.123249
# dtype: float64

# %%
var.plot.bar()

# %%
# Show the basic statistical information for the dataset
df.describe()
# Out:
#               x1         y1         x2         y2         x3         y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               x4         y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# The mean for x is the same for each dataset
#
# The standard deviation for y is the same for each dataset

# %%
# Line plot for x1,y1 values
sns.lmplot(x="x1",y="y1",data=df)
plt.show()

# %%
# Line plot for x2, y2 values
sns.lmplot(x="x2",y="y2",data=df)
plt.show()

# %%
# Line plot for x3, y3 values
sns.lmplot(x="x3",y="y3",data=df)
plt.show()

# %%
#Line plot for x4, y4 values
sns.lmplot(x="x4",y="y4",data=df)
plt.show()

# %%
df1 = pd.read_csv("Anscombes Dataset 2 columns.csv")

# %%
df1
# Out:
#     Dataset   x      y
# 0         1  10   8.04
# 1         1   8   6.95
# 2         1  13   7.58
# 3         1   9   8.81
# 4         1  11   8.33
# 5         1  14   9.96
# 6         1   6   7.24
# 7         1   4   4.26
# 8         1  12  10.84
# 9         1   7   4.82
# 10        1   5   5.68
# 11        2  10   9.14
# 12        2   8   8.14
# 13        2  13   8.74
# 14        2   9   8.77
# 15        2  11   9.26
# 16        2  14   8.10
# 17        2   6   6.13
# 18        2   4   3.10
# 19        2  12   9.13
# 20        2   7   7.26
# 21        2   5   4.74
# 22        3  10   7.46
# 23        3   8   6.77
# 24        3  13  12.74
# 25        3   9   7.11
# 26        3  11   7.81
# 27        3  14   8.84
# 28        3   6   6.08
# 29        3   4   5.39
# 30        3  12   8.15
# 31        3   7   6.42
# 32        3   5   5.73
# 33        4   8   6.58
# 34        4   8   5.76
# 35        4   8   7.71
# 36        4   8   8.84
# 37        4   8   8.47
# 38        4   8   7.04
# ...

# %%
# %matplotlib inline
# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="Dataset", hue="Dataset", data=df1,
           col_wrap=2, ci=None, palette="husl")

# %%
sns.pairplot(df1, hue="Dataset")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.pairplot(df)
plt.show()
